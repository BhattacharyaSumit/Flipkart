# %% [markdown]
# <a href="https://colab.research.google.com/github/BhattacharyaSumit/Flipkart/blob/master/crusades.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from zipfile import ZipFile

# %%
zf = ZipFile('drive/My Drive/Copy of image_mirror4.zip', 'r')
zf.extractall('Training1')
zf.close()

# %%
import cv2
import glob

# %%
import pandas as pd

# %%
train = pd.read_csv('training.csv')

# %%
test = pd.read_csv('test.csv')

# %%
import os
import matplotlib.pyplot as plt

# %%
folder_image=[]
names=[]
images =[]

# %%
for number,filename in enumerate(os.listdir('Training1/images')):
    folder_image.append(filename)

# %%
for name in train.image_name:
    if name in folder_image:
       names.append(name)

# %%
names_test=[]
for name in test.image_name:
    if name in folder_image:
       names_test.append(name)

# %%
#for name in names:  
    #df1=plt.imread('Training1/images/{}'.format(name))
    #images.append(df1)

# %%
len(names)
# Out:
# 14000

# %%
#import os
names_train=[]
def load_images_from_folder(folder):
    images = []
    #files={}
    for number,filename in enumerate(sorted(os.listdir(folder))):
      #files[number]= filename
    #for number , filename in files.items():
        if filename in names:
            img = cv2.imread(os.path.join(folder,filename))
            #b,g,r = cv2.split(img)
            #img = cv2.merge([r,g,b])
            img = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
            #img = cv2.resize(img ,(64,64))
            images.append(img)
            names_train.append(filename)
        
            
    return images

# %%
image2 = load_images_from_folder('Training1/images')

# %%
image2[0].shape
# Out:
# (480, 640)

# %%
plt.imshow(image2[13000])
plt.grid(None)
plt.show()

# %%
image[1987].shape
# Out:
# (64, 64)
